# %% [markdown]
# # Market Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#load dataset
df = pd.read_csv("SuperMarket Analysis.csv")

# %%
#load first five rows
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  579-15-5088      C  Naypyitaw        Member  Female
# 1  662-83-6878      B   Mandalay        Member    Male
# 2  994-59-5015      C  Naypyitaw        Member  Female
# 3  320-69-8296      C  Naypyitaw        Member  Female
# 4  388-16-1094      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity  Tax 5%    Sales       Date  \
# 0      Food and beverages       26.27         6   7.881  165.501  1/12/2019
# 1       Sports and travel       31.06         1   1.553   32.613  3/26/2019
# 2  Electronic accessories       84.35         2   8.435  177.135  2/11/2019
# 3      Food and beverages       88.60         1   4.430   93.030   3/5/2019
# 4       Health and beauty       46.44         9  20.898  438.858  2/23/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  11:11  Credit card  157.62                 4.761905         7.881     9.0
# ...

# %%
#load five last rows
df.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 995  385-91-7651      B   Mandalay        Normal    Male
# 996  242-29-1728      B   Mandalay        Member  Female
# 997  330-68-9422      A     Yangon        Member    Male
# 998  532-17-1426      C  Naypyitaw        Normal  Female
# 999  472-33-6190      A     Yangon        Normal    Male
#
#                Product line  Unit price  Quantity  Tax 5%    Sales       Date  \
# 995       Health and beauty       58.29         4  11.658  244.818  1/31/2019
# 996       Health and beauty       92.91         2   9.291  195.111  3/19/2019
# 997      Home and lifestyle       72.33         2   7.233  151.893  3/22/2019
# 998  Electronic accessories       74.13         2   7.413  155.673  3/23/2019
# 999  Electronic accessories       42.68        10  21.340  448.140  1/29/2019
#
#       Time  Payment    cogs  gross margin percentage  gross income  Rating
# 995  19:52     Cash  233.16                 4.761905        11.658     7.6
# ...

# %%
#load the data structure
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   str
#  1   Branch                   1000 non-null   str
#  2   City                     1000 non-null   str
#  3   Customer type            1000 non-null   str
#  4   Gender                   1000 non-null   str
#  5   Product line             1000 non-null   str
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Sales                    1000 non-null   float64
#  10  Date                     1000 non-null   str
#  11  Time                     1000 non-null   str
#  12  Payment                  1000 non-null   str
#  13  cogs                     1000 non-null   float64
# ...

# %%
#Statistical summary for 
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Sales        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     53.037400     5.411000    14.212496   298.462416   284.24992
# std      18.433486     2.879995     9.258579   194.430159   185.17158
# min      10.000000     1.000000     0.500000    10.500000    10.00000
# 25%      40.470000     3.000000     6.771750   142.206750   135.43500
# 50%      52.295000     5.000000    12.211000   256.431000   244.22000
# 75%      65.425000     8.000000    20.457000   429.597000   409.14000
# max     118.880000    10.000000    52.726500  1107.256500  1054.53000
#
#        gross margin percentage  gross income       Rating
# count              1000.000000   1000.000000  1000.000000
# mean                  4.761905     14.212496     7.054200
# std                   0.000000      9.258579     1.617139
# min                   4.761905      0.500000     4.000000
# ...

# %%
df.describe(include="all")
# Out:
#          Invoice ID Branch    City Customer type  Gender  \
# count          1000   1000    1000          1000    1000
# unique         1000      3       3             2       2
# top     579-15-5088      A  Yangon        Normal  Female
# freq              1    352     352           508     505
# mean            NaN    NaN     NaN           NaN     NaN
# std             NaN    NaN     NaN           NaN     NaN
# min             NaN    NaN     NaN           NaN     NaN
# 25%             NaN    NaN     NaN           NaN     NaN
# 50%             NaN    NaN     NaN           NaN     NaN
# 75%             NaN    NaN     NaN           NaN     NaN
# max             NaN    NaN     NaN           NaN     NaN
#
#                   Product line   Unit price     Quantity       Tax 5%  \
# count                     1000  1000.000000  1000.000000  1000.000000
# unique                       6          NaN          NaN          NaN
# ...

# %% [markdown]
# Q1. How many records and columns are in the dataset?

# %%
df.shape
# Out:
# (1000, 17)

# %% [markdown]
# Q2. Are there missing values or duplicate records?

# %% [markdown]
#  #Check missing values

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Sales                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# #To check the duplicate data

# %%
duplicates = df.duplicated().sum()
print("Number of duplicate rows:", duplicates)
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# Q3. What is the total sales/revenue?

# %%
total_sales = df['Sales'].sum()
print(total_sales)
# Out:
# 298462.41599999997

# %% [markdown]
# Q4. What is the average transaction value?

# %%
average_sales = df['Sales'].mean()
print(average_sales)
# Out:
# 298.46241599999996

# %% [markdown]
# Q5. Which product line generated the highest total sales?

# %%
product_sales = df.groupby('Product line')['Sales'].sum().sort_values(ascending=False)

print(product_sales)
# Out:
# Product line
# Electronic accessories    64194.2175
# Health and beauty         55203.8445
# Sports and travel         50396.4825
# Fashion accessories       43328.2920
# Food and beverages        43277.8080
# Home and lifestyle        42061.7715
# Name: Sales, dtype: float64

# %% [markdown]
# Q6. Which product line had the highest quantity sold?

# %%
quantity_product = (
    df.groupby('Product line')['Quantity']
    .sum()
    .sort_values(ascending=False)
)

# %%
print(quantity_product)
# Out:
# Product line
# Electronic accessories    1038
# Health and beauty          983
# Food and beverages         916
# Sports and travel          837
# Home and lifestyle         832
# Fashion accessories        805
# Name: Quantity, dtype: int64

# %% [markdown]
# Q7. Which branch generated the highest total sales?

# %%
branch_sales = df.groupby('Branch')['Sales'].sum().sort_values(ascending=False)

# %%
print(branch_sales)
# Out:
# Branch
# A    107049.558
# C     97169.268
# B     94243.590
# Name: Sales, dtype: float64

# %% [markdown]
# Visualization

# %%
branch_sales.plot(kind='bar', figsize=(7,5))
# Out:
# <Axes: xlabel='Branch'>

# %%
plt.title('Total Sales by Branch')
plt.xlabel('Branch')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# Q8. Which customer type generated the highest total sales?

# %%
customer_sales = df.groupby('Customer type')['Sales'].sum()

print(customer_sales)
# Out:
# Customer type
# Member    148329.699
# Normal    150132.717
# Name: Sales, dtype: float64

# %% [markdown]
# Q9. Which payment method was used most frequently?

# %%
payment_frequency = df['Payment'].value_counts()

print(payment_frequency)
# Out:
# Payment
# Cash           370
# Ewallet        331
# Credit card    299
# Name: count, dtype: int64

# %% [markdown]
# Visualization

# %%
payment_frequency.plot(kind='bar')

plt.title('Payment Method Frequency')
plt.xlabel('Payment Method')
plt.ylabel('Number of Transactions')
plt.show()

# %% [markdown]
# Q10. Which gender generated the highest total sales?

# %%
gender_sales = df.groupby('Gender')['Sales'].sum().sort_values(ascending=False)

print(gender_sales)
# Out:
# Gender
# Female    154917.483
# Male      143544.933
# Name: Sales, dtype: float64

# %% [markdown]
# Q11. Which month had the highest total sales?

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Month'] = df['Date'].dt.month_name()

# %%
monthly_sales = df.groupby('Month')['Sales'].sum().sort_values(ascending=False)

# %%
print(monthly_sales)
# Out:
# Month
# March       105977.4030
# February     98976.3285
# January      93508.6845
# Name: Sales, dtype: float64

# %% [markdown]
# Visualization

# %%
monthly_sales.plot(kind='bar')

plt.title('Monthly Sales')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# Q12. Which day of the week had the highest sales?

# %%
df['Day'] = df['Date'].dt.day_name()

# %%
daily_sales = df.groupby('Day')['Sales'].sum().sort_values(ascending=False)

# %%
print(daily_sales)
# Out:
# Day
# Saturday     61929.7350
# Friday       50969.5935
# Thursday     45671.8710
# Wednesday    38400.8415
# Sunday       34565.4330
# Tuesday      33936.1155
# Monday       32988.8265
# Name: Sales, dtype: float64

# %% [markdown]
# Q13. Which product line has the highest average transaction value?

# %%
average_product_sales = (
    df.groupby('Product line')['Sales']
    .mean()
    .sort_values(ascending=False)
)

# %%
print(average_product_sales)
# Out:
# Product line
# Electronic accessories    339.651944
# Sports and travel         325.138597
# Fashion accessories       311.714331
# Health and beauty         298.399159
# Home and lifestyle        267.909373
# Food and beverages        247.301760
# Name: Sales, dtype: float64

# %% [markdown]
# Q14. Is there a relationship between quantity sold and total sales?

# %%
plt.figure(figsize=(8, 5))

plt.bar(df['Quantity'], df['Sales'])

plt.title('Quantity Sold vs Total Sales')
plt.xlabel('Quantity Sold')
plt.ylabel('Total Sales')

plt.show()

# %% [markdown]
# Calculate correlation

# %%
df['Quantity'].corr(df['Sales'])
# Out:
# np.float64(0.7948656857330789)

# %% [markdown]
# Q15. Create a correlation heatmap

# %% [markdown]
# Step 1
#
# Select numerical variables:

# %%
numeric_df = df.select_dtypes(include='number')

# %% [markdown]
# Step 2: Create heatmap

# %%
plt.figure(figsize=(8,5))

sns.heatmap(
    numeric_df.corr(),
    annot=True,
    cmap='coolwarm',
    fmt='.2f'
)

plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Q16. Identify potential outliers in total sales

# %%
#Use a box plot:
plt.figure(figsize=(8,5))

plt.boxplot(df['Sales'])

plt.title('Box Plot of Total Sales')
plt.ylabel('Sales')

plt.show()

# %%
#Using the IQR method
Q1 = df['Sales'].quantile(0.25)
Q3 = df['Sales'].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[
    (df['Sales'] < lower) |
    (df['Sales'] > upper)
]

print("Lower limit:", lower)
print("Upper limit:", upper)
print("Number of outliers:", len(outliers))
# Out:
# Lower limit: -288.878625
# Upper limit: 860.682375
# Number of outliers: 9

# %% [markdown]
# Q17. Dashboard-style visualizations

# %%
#Visualization 1 — Sales by Product Line
df.groupby('Product line')['Sales'].sum().plot(kind='bar')

plt.title('Sales by Product Line')
plt.ylabel('Sales')
plt.show()

# %%
#Visualization 2 — Sales by Branch
df.groupby('Branch')['Sales'].sum().plot(kind='bar')

plt.title('Sales by Branch')
plt.ylabel('Sales')
plt.show()

# %%
#Visualization 3 — Monthly Sales
monthly_sales.plot(kind='line', marker='o')

plt.title('Monthly Sales Trend')
plt.ylabel('Sales')
plt.show()

# %%
#Visualization 4 — Quantity vs Sales
plt.scatter(df['Quantity'], df['Sales'])

plt.title('Quantity vs Sales')
plt.xlabel('Quantity')
plt.ylabel('Sales')
plt.show()

# %%
#Visualization 5 — Sales Distribution
plt.hist(df['Sales'], bins=20)

plt.title('Distribution of Sales')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()

# %%
#Visualization 6 — Correlation Heatmap
plt.figure(figsize=(10,7))

sns.heatmap(
    df.select_dtypes(include='number').corr(),
    annot=True,
    cmap='coolwarm'
)

plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Q18. Five key business insights

# %% [markdown]
# # Five Key business insights
# Insight 1 — Electronic accessories are the strongest product category
#
# Electronic accessories generated the highest total sales:
#
# 64,194.22
# 	​
#
#
# They also had the highest quantity sold, at 1,038 units.
#
# Insight 2 — Branch A is the strongest branch
#
# Branch A generated approximately:
#
# 107,049.56
# 	​
#
#
# This is the highest among the three branches.
#
# Insight 3 — Saturday is the strongest sales day
#
# Saturday generated approximately:
#
# 61,929.74
# 	​
#
#
# This indicates significantly stronger sales activity on Saturdays.
#
# Insight 4 — March was the strongest month
#
# March generated:
#
# 105,977.40
# 	​
#
#
# Therefore, sales increased from January through March.
#
# Insight 5 — Quantity strongly influences sales
#
# The correlation between quantity and sales is approximately:
#
# 0.795
# 	​
#
#
# Therefore, selling more units generally results in higher transaction revenue.
#
# The practical specifically asks for five key business insights.

# %% [markdown]
# # Three recommendations for management
# Recommendation 1 — Increase inventory of electronic accessories
#
# Since electronic accessories have the highest sales and quantity sold, management should ensure that popular electronic products remain adequately stocked.
#
# Recommendation 2 — Prepare for high-demand periods
#
# Saturday and March have the highest sales. Management should consider:
#
# Increasing stock before Saturdays
# Increasing staffing during busy periods
# Running promotions during high-demand periods
# Ensuring sufficient payment facilities
# Recommendation 3 — Improve sales of weaker product lines
#
# Home and lifestyle and Food and beverages have comparatively lower total sales.
#
# Management should investigate:
#
# Customer preferences
# Product pricing
# Promotions
# Product placement
# Discounts and bundles
#
# The assignment requires three management recommendations based on the analysis.

# %% [markdown]
# # Final conclusion
#
# The analysis of the 1,000 supermarket transactions shows total sales of approximately 298,462.42, with an average transaction value of approximately 298.46. Electronic accessories were the strongest product line, while Branch A generated the highest branch sales. Normal customers produced slightly more sales than Members, and female customers generated more sales than male customers.
#
# March was the best-performing month and Saturday was the strongest sales day. The strong positive correlation between quantity sold and sales indicates that transaction revenue generally increases as customers purchase more items. The analysis also identified nine unusually high-sales transactions that can be investigated as potential outliers.
#
# Overall, management should focus on maintaining stock of high-performing products, preparing resources for high-demand periods, and improving the performance of weaker product categories.
#
# The practical's required final deliverables are a completed notebook, visualizations, written interpretations, five insights, three recommendations, and a conclusion.
